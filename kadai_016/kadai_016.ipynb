# %%
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def check_adult(self):
        # 名前（self.name）をメッセージに含めるよう修正
        if self.age >= 20:
            print(f"{self.name}さんは大人です")
        else:
            print(f"{self.name}さんは大人ではありません")

# 1. 複数のHumanインスタンスを作成
human1 = Human("髙田", 37)
human2 = Human("佐藤", 15)
human3 = Human("田中", 20)

# 2. インスタンスをリストにまとめる
human_list = [human1, human2, human3]

# 3. リストに対して繰り返し処理を行い、各インスタンスのメソッドを呼び出す
for human in human_list:
    human.check_adult()
# Out:
# 髙田さんは大人です
# 佐藤さんは大人ではありません
# 田中さんは大人です
