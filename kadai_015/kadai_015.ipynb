# %%
class Human:
  def __init__(self):
    self.name = "takata"
    self.age = "36"

  def printinfo(self):
    print(self.name)
    print(self.age)

human = Human()
human.printinfo()
# Out:
# takata
# 36
