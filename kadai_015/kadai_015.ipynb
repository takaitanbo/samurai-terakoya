# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def printinfo(self):
    print(self.name)
    print(self.age)

human = Human("髙田","36歳")
human.printinfo()
# Out:
# 髙田
# 36歳
