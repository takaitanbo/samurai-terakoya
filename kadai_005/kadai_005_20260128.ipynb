# %%
#課題：変数を使って四則演算しよう

#上辺：10cm
top_side = 10

#下辺：20cm
bottom_side = 20

#高さ：5cm
height = 5

#台形の面積 =（上辺＋下辺）× 高さ ÷ 2
menseki = (top_side + bottom_side) * height / 2

#回答
print(f"{menseki}㎠")
# Out:
# 75.0㎠
